# %% [markdown]
# # Skewness

# %%
import pandas as pd

# %%
df = pd.read_csv('carprice.csv')

# %%
df.head()
# Out:
#    symboling               CarName fueltype aspiration doornumber  \
# 0          2           audi 100 ls      gas        std       four
# 1          0           peugeot 504      gas        std       four
# 2          3  mitsubishi outlander      gas      turbo        two
# 3          1         toyota corona      gas        std        two
# 4          2       toyota cressida      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0        sedan        fwd          front       99.8      176.6  ...
# 1        wagon        rwd          front      114.2      198.9  ...
# 2    hatchback        fwd          front       95.9      173.2  ...
# 3    hatchback        fwd          front       95.7      158.7  ...
# 4  convertible        rwd          front       98.4      176.2  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         109        mpfi       3.19   3.40             10.0         102
# ...

# %%
import seaborn as sns
sns.displot(data=df, x='price',kind="kde")

# %%
sns.displot(data=df, x='wheelbase',kind="kde")

# %%
df['wheelbase'].std()
# Out:
# 6.38499067816586

# %%
df['carlength'].std()
# Out:
# 12.971747030723455

# %%
sns.displot(data=df, x='carlength',kind="kde")

# %% [markdown]
# ![](https://i.ytimg.com/vi/IaTFpp-uzp0/maxresdefault.jpg)

# %% [markdown]
# ![](https://d138zd1ktt9iqe.cloudfront.net/media/seo_landing_files/standard-deviation-1626765925.png)

# %% [markdown]
# ![](https://excelrcom.b-cdn.net/assets/admin/ckfinder/userfiles/images/tableau1/tableau2/tableau3/tableau4/tableau5/tableau6/skewness-kurtosis_1JPG-.jpg)
