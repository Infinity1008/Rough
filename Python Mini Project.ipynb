# %% [markdown]
# ### Spotify makes new songs recommendations to users every week based on the songs that are currently saved in their playlists.
#
# ### Using the below dictionary which is a collection of playlists mantained by 'other' sample users, recommend songs to a new user.
#
# Use the below points as guidelines:
# * Pass in a list the songs currently listed by a new user. This can have entries like SONGID01,SONGID02,...
# * Find a playlist in the dictionary, where ALL of these songs are present (there can be more than 1 such playlist)
# * From this playlist(s), pick the remaining songs and recommend to the new user (refer below examples for more details)

# %% [markdown]
# # This code generates the existing playlist for you.
# ### Use this playlist to create your solution

# %%
# Don't edit this cell, this create your playlist
import random,string
songids=['SONGID'+str(i).zfill(2) for i in range(1,21)]
userid=[''.join('USER')+str(random.randint(10,99)).zfill(2) for i in range(100)]
playlist={i:j for i,j in zip(userid,[random.sample(songids,random.randint(4,7)) for i in range(len(userid))])}
playlist
# Out:
# {'USER90': ['SONGID03', 'SONGID16', 'SONGID10', 'SONGID01', 'SONGID06'],
#  'USER86': ['SONGID01',
#   'SONGID14',
#   'SONGID20',
#   'SONGID07',
#   'SONGID06',
#   'SONGID18'],
#  'USER11': ['SONGID03',
#   'SONGID05',
#   'SONGID13',
#   'SONGID12',
#   'SONGID10',
#   'SONGID19'],
#  'USER58': ['SONGID11',
#   'SONGID14',
#   'SONGID15',
#   'SONGID09',
#   'SONGID19',
#   'SONGID08'],
#  'USER61': ['SONGID03',
#   'SONGID05',
#   'SONGID15',
#   'SONGID06',
#   'SONGID16',
#   'SONGID10'],
#  'USER67': ['SONGID03',
#   'SONGID05',
#   'SONGID13',
#   'SONGID16',
#   'SONGID01',
#   'SONGID09'],
#  'USER16': ['SONGID06', 'SONGID03', 'SONGID11', 'SONGID20'],
#  'USER65': ['SONGID07',
#   'SONGID13',
#   'SONGID06',
#   'SONGID20',
#   'SONGID01',
#   'SONGID11'],
#  'USER95': ['SONGID12', 'SONGID15', 'SONGID08', 'SONGID14', 'SONGID20'],
#  'USER49': ['SONGID20',
#   'SONGID14',
#   'SONGID10',
#   'SONGID13',
#   'SONGID17',
#   'SONGID08'],
#  'USER14': ['SONGID10', 'SONGID12', 'SONGID03', 'SONGID20'],
#  'USER22': ['SONGID06', 'SONGID02', 'SONGID15', 'SONGID13', 'SONGID12'],
#  'USER43': ['SONGID03',
#   'SONGID13',
#   'SONGID15',
#   'SONGID19',
#   'SONGID08',
#   'SONGID01',
#   'SONGID07'],
#  'USER62': ['SONGID02', 'SONGID08', 'SONGID04', 'SONGID06'],
#  'USER20': ['SONGID14',
#   'SONGID18',
#   'SONGID13',
#   'SONGID01',
#   'SONGID12',
#   'SONGID03'],
#  'USER56': ['SONGID12',
#   'SONGID02',
#   'SONGID16',
#   'SONGID09',
#   'SONGID10',
#   'SONGID04',
#   'SONGID20'],
#  'USER54': ['SONGID03', 'SONGID19', 'SONGID01', 'SONGID04', 'SONGID08'],
#  'USER70': ['SONGID05', 'SONGID17', 'SONGID20', 'SONGID01', 'SONGID10'],
#  'USER36': ['SONGID11',
#   'SONGID09',
#   'SONGID01',
#   'SONGID02',
#   'SONGID16',
#   'SONGID10',
#   'SONGID15'],
#  'USER88': ['SONGID14', 'SONGID01', 'SONGID15', 'SONGID07'],
#  'USER68': ['SONGID18',
#   'SONGID05',
#   'SONGID06',
#   'SONGID15',
#   'SONGID16',
#   'SONGID02',
#   'SONGID09'],
#  'USER35': ['SONGID07', 'SONGID08', 'SONGID20', 'SONGID12', 'SONGID10'],
#  'USER81': ['SONGID13', 'SONGID11', 'SONGID04', 'SONGID18', 'SONGID19'],
#  'USER94': ['SONGID02',
#   'SONGID20',
#   'SONGID13',
#   'SONGID05',
#   'SONGID01',
#   'SONGID18'],
#  'USER92': ['SONGID10',
#   'SONGID19',
#   'SONGID01',
#   'SONGID07',
#   'SONGID02',
#   'SONGID03'],
#  'USER38': ['SONGID12',
#   'SONGID14',
#   'SONGID05',
#   'SONGID06',
#   'SONGID10',
#   'SONGID08',
#   'SONGID02'],
#  'USER74': ['SONGID20', 'SONGID15', 'SONGID05', 'SONGID18', 'SONGID11'],
#  'USER21': ['SONGID03', 'SONGID18', 'SONGID01', 'SONGID02'],
#  'USER34': ['SONGID14',
#   'SONGID02',
#   'SONGID09',
#   'SONGID11',
#   'SONGID08',
#   'SONGID15',
#   'SONGID07'],
#  'USER13': ['SONGID02', 'SONGID08', 'SONGID06', 'SONGID01', 'SONGID19'],
#  'USER47': ['SONGID10', 'SONGID19', 'SONGID05', 'SONGID11'],
#  'USER42': ['SONGID01', 'SONGID19', 'SONGID14', 'SONGID03', 'SONGID08'],
#  'USER17': ['SONGID10', 'SONGID16', 'SONGID19', 'SONGID14', 'SONGID15'],
#  'USER73': ['SONGID17', 'SONGID11', 'SONGID15', 'SONGID16'],
#  'USER10': ['SONGID13',
#   'SONGID07',
#   'SONGID19',
#   'SONGID17',
#   'SONGID08',
#   'SONGID10',
#   'SONGID02'],
#  'USER32': ['SONGID19',
#   'SONGID12',
#   'SONGID07',
#   'SONGID15',
#   'SONGID13',
#   'SONGID20'],
#  'USER79': ['SONGID10',
#   'SONGID15',
#   'SONGID02',
#   'SONGID11',
#   'SONGID12',
#   'SONGID19',
#   'SONGID20'],
#  'USER66': ['SONGID01', 'SONGID10', 'SONGID18', 'SONGID06', 'SONGID08'],
#  'USER39': ['SONGID17', 'SONGID16', 'SONGID04', 'SONGID09'],
#  'USER15': ['SONGID13',
#   'SONGID03',
#   'SONGID09',
#   'SONGID20',
#   'SONGID18',
#   'SONGID06',
#   'SONGID19'],
#  'USER75': ['SONGID16',
#   'SONGID07',
#   'SONGID11',
#   'SONGID05',
#   'SONGID06',
#   'SONGID01'],
#  'USER52': ['SONGID08',
#   'SONGID11',
#   'SONGID02',
#   'SONGID06',
#   'SONGID17',
#   'SONGID10',
#   'SONGID14'],
#  'USER24': ['SONGID03', 'SONGID05', 'SONGID13', 'SONGID02', 'SONGID09'],
#  'USER29': ['SONGID15',
#   'SONGID19',
#   'SONGID03',
#   'SONGID08',
#   'SONGID04',
#   'SONGID20',
#   'SONGID06'],
#  'USER44': ['SONGID14',
#   'SONGID04',
#   'SONGID15',
#   'SONGID10',
#   'SONGID06',
#   'SONGID17'],
#  'USER48': ['SONGID16',
#   'SONGID15',
#   'SONGID18',
#   'SONGID01',
#   'SONGID02',
#   'SONGID06'],
#  'USER40': ['SONGID11', 'SONGID05', 'SONGID13', 'SONGID07'],
#  'USER51': ['SONGID10',
#   'SONGID04',
#   'SONGID20',
#   'SONGID05',
#   'SONGID14',
#   'SONGID16'],
#  'USER60': ['SONGID19',
#   'SONGID05',
#   'SONGID11',
#   'SONGID07',
#   'SONGID13',
#   'SONGID03'],
#  'USER72': ['SONGID07', 'SONGID04', 'SONGID06', 'SONGID18', 'SONGID19'],
#  'USER87': ['SONGID03', 'SONGID19', 'SONGID02', 'SONGID05'],
#  'USER91': ['SONGID11', 'SONGID07', 'SONGID06', 'SONGID03', 'SONGID13'],
#  'USER19': ['SONGID07', 'SONGID05', 'SONGID10', 'SONGID13'],
#  'USER18': ['SONGID17', 'SONGID19', 'SONGID05', 'SONGID14'],
#  'USER85': ['SONGID19', 'SONGID20', 'SONGID17', 'SONGID07'],
#  'USER89': ['SONGID09', 'SONGID08', 'SONGID17', 'SONGID18', 'SONGID14'],
#  'USER28': ['SONGID06',
#   'SONGID13',
#   'SONGID08',
#   'SONGID18',
#   'SONGID02',
#   'SONGID12'],
#  'USER27': ['SONGID11', 'SONGID05', 'SONGID03', 'SONGID07'],
#  'USER64': ['SONGID03',
#   'SONGID08',
#   'SONGID01',
#   'SONGID10',
#   'SONGID12',
#   'SONGID02']}

# %% [markdown]
# Let's say the new user has listened to these 3 songs

# %%
myplist=['SONGID01','SONGID06','SONGID16']

# %% [markdown]
# What songs would you recommend him.

# %% [markdown]
# # Answer
# Write your answer here
