# %% [markdown]
# Question. 1-
#
# Answer- Since the average selling price of an article is  Rs 250 with a standard deviation of Rs 47.00 suggest that there is some variability in the prices of food items at the restaurant. The median value being close to the mean of Rs 202.00 indicates that the distribution of prices is relatively symmetrical.
# The median value being close to the mean of Rs 202.00 indicates that the distribution of prices is relatively symmetrical so one can become a regular customer to the restaurant. But in my opinion Whether or not you would become a regular customer of the restaurant depends on several factors beyond just the statistics of the price distribution.Some factors you might consider are your personal budget, the quality of the food and service, the restaurant's ambiance, location, and the overall value you perceive for the price you would pay.

# %% [markdown]
# Question. 2
#
# Answer- 1) The average size of a house in the residential locality is 2224 square feet.
#  2) The standard deviation of the house sizes is 248 square feet, indicating some variability in the sizes.
#  3) The median value of the house sizes is 2220 square feet.
#
# Since the median value is very close to the average size, it suggests that the distribution of house sizes is relatively symmetrical. However, without further information or a comparison to other localities, it is difficult to determine if the houses in this specific locality are bigger or smaller on average.
#
# To make a definitive conclusion about the size of houses in this locality, it would be helpful to compare it with other localities or have more data for comparison.

# %% [markdown]
# Question. 3
#
# Answer- To determine which locality is best for investment, we can compare the house prices in locality X and locality Y using statistical measures. Here, we can calculate the mean and median for both localities and analyze the results.
#
# For locality X:
# House prices: 2.00 L, 10.00 L, 8.00 L, 12.00 L
#
# Mean = (2.00 + 10.00 + 8.00 + 12.00) / 4 = 32.00 L / 4 = 8.00 L
#
# Median = (8.00 + 10.00) / 2 = 9.00 L
#
# For locality Y:
# House prices: 2.50 L, 9.50 L, 8.15 L, 12.50 L
#
# Mean = (2.50 + 9.50 + 8.15 + 12.50) / 4 = 32.65 L / 4 = 8.1625 L
#
# Median = (8.15 + 9.50) / 2 = 8.825 L
#
# Comparing the mean and median for both localities:
#
# Locality X:
# Mean = 8.00 L
# Median = 9.00 L
#
# Locality Y:
# Mean = 8.1625 L
# Median = 8.825 L
#
# Based on the mean and median values, we can see that the average house price (mean) in locality Y is slightly higher than that in locality X. However, the median house price in locality X is higher than that in locality Y.
#
# To make a more informed decision, it is recommended to consider additional factors such as the, the overall real estate market conditions, future development plans, location advantages, and other economic indicators of the respective localities.

# %% [markdown]
# Question. 4
#
# Answer- A) The class interval with the highest frequency is the "35 - 45" age group, with 23 patients.
#
# B) The age group that was affected the least is the "55 - 65" age group, with only 5 patients.
#
# c) The number of patients of age 45 years and above can be obtained by summing the frequencies of the age groups "45 - 55" and "55 - 65". In this case, it is 14 + 5 = 19 patients.
#
# D) The modal class interval is the age group with the highest frequency. In this case, the "35 - 45" age group has the highest frequency of 23 patients, making it the modal class interval.

# %% [markdown]
# Question. 5
#
# Answer- To compute the average return on investment for the given data, you can use the arithmetic mean method. The arithmetic mean is a commonly used average method that calculates the sum of all the values and divides it by the number of values.
#
# In this case, We will calculate the average return on investment based on the returns for each year.
#
# Year | Return
# 2015 | 36%
# 2016 | 23%
# 2017 | -48%
# 2018 | -30%
# 2019 | 15%
# 2020 | 31%
#
# To compute the average return:
#
#  36% + 23% + (-48%) + (-30%) + 15% + 31% = 27%
#
#  27% / 6 = 4.5%
#
# The average return on investment for the given data is 4.5%.

# %% [markdown]
# Question. 6
#
# Answer- Measuring the height of all men on Earth is an enormous task and practically impossible to accomplish. However, if such an endeavor were attempted, it would require a well-planned and representative sampling strategy. Here is a suggested approach:
#
# Define the target population: Determine the specific criteria for identifying the population of men whose heights will be measured. This could include factors such as age range, geographical locations, ethnic diversity, and other relevant characteristics.
#
# Sampling method: Select a sampling method that allows for a representative sample of the target population. Random sampling techniques, such as simple random sampling or stratified random sampling, can be employed to ensure fairness and reduce bias.
#
# Sample size determination: Decide on an appropriate sample size that balances accuracy and feasibility. Larger sample sizes generally provide more reliable estimates but also require more resources and time to measure.
#
# Sampling locations: Identify the locations from which the sample will be drawn. Consider sampling from various regions, countries, or continents to ensure a diverse representation.
#
# Data collection: Determine the most efficient and practical method to collect height measurements. This could involve using height measuring instruments, such as stadiometers or height scales, and training personnel to conduct accurate measurements. Remote data collection methods, such as self-reported heights, could also be considered, although they may introduce potential measurement errors.
#
# Ethical considerations: Ensure that appropriate ethical guidelines and informed consent procedures are followed when collecting data from individuals.
#
# Data analysis: Analyze the collected height data to determine statistical measures such as mean, median, and standard deviation, which can provide insights into the overall height distribution of the sampled population.

# %% [markdown]
# Questtion. 8
#
# Answer- Based on the variables provided, here is a statistical summary for each variable in the dataset:
#
# Age:
#
# Count
# Mean
# Standard deviation
# Minimum value
# 25th percentile (Q1)
# Median (Q2 or 50th percentile)
# 75th percentile (Q3)
# Maximum value
#
# Experience:
# Count
# Mean
# Standard deviation
# Minimum value
# 25th percentile (Q1)
# Median (Q2 or 50th percentile)
# 75th percentile (Q3)
# Maximum value
#
# Income:
# Count
# Mean
# Standard deviation
# Minimum value
# 25th percentile (Q1)
# Median (Q2 or 50th percentile)
# 75th percentile (Q3)
# Maximum value
#
# ZIPCode:
# Count
# Number of unique ZIP codes
#
# Family:
# Count
# Mean
# Standard deviation
# Minimum value
# 25th percentile (Q1)
# Median (Q2 or 50th percentile)
# 75th percentile (Q3)
# Maximum value
#
# CCAvg:
# Count
# Mean
# Standard deviation
# Minimum value
# 25th percentile (Q1)
# Median (Q2 or 50th percentile)
# 75th percentile (Q3)
# Maximum value
#
# Education:
# Count
# Number of unique education levels
# Frequency distribution of education levels
#
# Mortgage:
# Count
# Mean
# Standard deviation
# Minimum value
# 25th percentile (Q1)
# Median (Q2 or 50th percentile)
# 75th percentile (Q3)
# Maximum value
#
# Personal Loan:
# Count
# Number of customers who accepted personal loans
# Number of customers who did not accept personal loans
#
# Securities Account:
# Count
# Number of customers with securities accounts
# Number of customers without securities accounts
#
# CD Account:
# Count
# Number of customers with certificate of deposit (CD) accounts
# Number of customers without CD accounts
#
# Online:
# Count
# Number of customers who use internet banking facilities
# Number of customers who do not use internet banking facilities
#
# CreditCard:
# Count
# Number of customers who use credit cards issued by UniversalBank
# Number of customers who do not use UniversalBank credit cards.
#
#
# The statistical summary will provide descriptive statistics for numerical variables and frequency counts for categorical variables.

# %% [markdown]
# Question. 9
#
# Answer- Here are the measures of central tendency for the quantitative variables (both continuous and discrete):
#
# Age:
# Mean (average age)
# Median (middle value of age)
# Mode (most common age)
# Range (difference between the maximum and minimum age values)
#
# Experience:
# Mean (average years of experience)
# Median (middle value of years of experience)
# Mode (most common years of experience)
# Range (difference between the maximum and minimum years of experience values)
#
# Income:
# Mean (average annual income)
# Median (middle value of annual income)
# Mode (most common annual income)
# Range (difference between the maximum and minimum annual income values)
# Family:
#
# Mean (average family size)
# Median (middle value of family size)
# Mode (most common family size)
# Range (difference between the maximum and minimum family size values)
#
# CCAvg:
# Mean (average monthly credit card spending)
# Median (middle value of monthly credit card spending)
# Mode (most common monthly credit card spending)
# Range (difference between the maximum and minimum monthly credit card spending values)
#
# Mortgage:
# Mean (average value of house mortgage)
# Median (middle value of house mortgage)
# Mode (most common value of house mortgage)
# Range (difference between the maximum and minimum values of house mortgage)
#
# For discrete variables like Education, Personal Loan, Securities Account, CD Account, Online, and CreditCard, the measures of central tendency are the mode and the frequency distribution .

# %% [markdown]
# Question. 10
#
# Answer- Correlation measures the strength and direction of the linear relationship between two variables. In this case, we can calculate the correlation coefficient between the "Age" and "Experience" variables to determine if there is any similarity in their distribution patterns.
#
# Correlation analysis: Correlation measures the strength and direction of the linear relationship between two variables. By calculating the correlation coefficient, We can determine if there is a similarity in the distribution of "Age" and "Experience." The correlation coefficient ranges from -1 to 1. A value close to 1 indicates a strong positive correlation, while a value close to -1 indicates a strong negative correlation. A value close to 0 suggests no significant correlation.
#
# Scatter plot: A scatter plot visually represents the relationship between two variables. By plotting "Age" on the x-axis and "Experience" on the y-axis, you can observe the pattern of the data points. If there is a similarity in the distribution, We may see a trend or pattern in the scatter plot.

# %% [markdown]
# Question. 11
#
# Answer- To determine the most frequent family members present in the dataset, I will count the occurrences of each family member. It appears that the numbers represent the family members. Here are the counts for each family member:
#
# Family 1: 1097 occurrences
# Family 2: 1011 occurrences
# Family 3: 1016 occurrences
# Family 4: 1115 occurrences
#
# From the counts, we can see that Family 4 is the most frequent family member in the dataset, appearing 1115 times.

# %% [markdown]
# Question. 12
#
# Answer-  Coefficient of Variation = (Standard Deviation / Mean) * 100
#
# Standard Deviation- 48.943
#
# Mean- 92.778
#
# Coefficient of Variation= 48.943/92.778*100
#
# Coefficient of Variation= 52.199

# %% [markdown]
# Question.13
#
# Answer- Imputing missing or zero values in the 'Mortgage' variable can be done using various business logical approaches.
#
# One possible approach is to impute the missing or zero values with the median value of the non-zero 'Mortgage' values. The median is a robust measure of central tendency and is less sensitive to outliers compared to the mean.

# %% [markdown]
# Question. 16
#
# Answer- 1st Decile: 8
# 2nd Decile: 10
# 3rd Decile: 11
# 4th Decile: 12
# 5th Decile: 13
# 6th Decile: 14
# 7th Decile: 15
# 8th Decile: 15
# 9th Decile: 15
# 10th Decile:15
#
# These deciles indicate the values below which a certain percentage of the data falls. For example, the 2nd decile represents the value below which 20% of the data falls.

# %% [markdown]
# Question.18
#
# Answer- By looking at the dataset provided to us we can clearly see that,
#
# Higher income holders spend more on credit cards.

# %% [markdown]
# Question.17
#
# AnswerThe variables that are quantitative and continuous are:
#
# ID
# Experience
# Income
# CCAvg
# Mortgage
#
# Experience: IQR: Q3 - Q1 = 30 - 16 = 14
#
# Income: IQR: Q3 - Q1 = 80 - 39 = 41
#
#
# CCAvg: IQR: Q3 - Q1 = 3.8 - 0.7 = 3.1
#
#
# Mortgage: IQR: Q3 - Q1 = 168 - 0 = 168

# %% [markdown]
# Question.14
#
# Answer- Customers with credit cards have more of experienece and more income than people having less experienece and less income.
