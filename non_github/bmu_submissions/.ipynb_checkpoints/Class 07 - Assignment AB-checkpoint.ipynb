# %% [markdown]
# # Assignment

# %% [markdown]
# You have already picked out the dataset you want to work with.
#
# ----
#
# # Question
# 1. EDA, i want to see some insights, present it neatly.
# 2. Fit a Decision Tree Regressor model on your data.
# 3. I want to see the training and testing accuracy of your model. So do split your data before modelling.
#
#
# ### Brownie Points (Extra 15 points)
# - Lastly, i want to see a function where i can input my values and get a prediction of whatever you are trying to predict. Think this through !!.
#
#
#
# Best of luck !!
#
# ![](https://media.tenor.com/mUVjXo5LhsQAAAAC/kakashi-yes.gif)

# %% [markdown]
# ### Choosing a dataset

# %% [markdown]
# Decision Tree Regressor is used for regression tasks where the target variable is continuous, such as predicting a person's income or the price of a house

# %% [markdown]
# #### The most relevent & interesting  dataset that i could find for this task was-
# #### Data Science jobs salaries on Kaggle

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Data  preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/works/Documents/BA/Data Science Jobs Salaries.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
# ...

# %%
df.describe()
# Out:
#              salary  salary_in_usd  remote_ratio
# count  2.450000e+02     245.000000    245.000000
# mean   5.025418e+05   99868.012245     69.183673
# std    2.276230e+06   83983.326949     37.593421
# min    4.000000e+03    2876.000000      0.000000
# 25%    6.000000e+04   45896.000000     50.000000
# 50%    1.030000e+05   81000.000000    100.000000
# 75%    1.740000e+05  130000.000000    100.000000
# max    3.040000e+07  600000.000000    100.000000

# %% [markdown]
# ##### Checking for null values

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### Mean salary vs level of experience

# %%
arr = np.array(df.groupby('experience_level').salary.median())

exp_lev = np.array(['EN','EX','MI','SE'])

fig, ax = plt.subplots()

ax.bar(exp_lev,arr)
ax.set_title("Mean salary by each experience level",fontdict={'size':16,'color':'red'})
ax.set_xlabel("Experience level",fontdict={'size':13,'color':'red'})
ax.set_ylabel("Salary",fontdict={'size':13,'color':'red'})
ax.grid()

fig.set_size_inches(8,8)
plt.show()

# %% [markdown]
#  Executives(EX) have the highest salary, followed by SE which have 2nd highest median salary

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Salary distribution

# %%
g = sns.displot(x=df['salary_in_usd'], data=df, kde=True)
plt.title('Distribution of salary in USD')
g.fig.set_figwidth(10)
g.fig.set_figheight(6)

# %% [markdown]
# #### *The above distribution charts illustrate the distribution of salaries in USD, from lowest to highest salaries.
#
# #### *As you can see, the majority of salaries fall between $80 - $90K. The highest wage is merely $600,000.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Salary vs type of employement

# %%
sns.boxplot(x='employment_type', y='salary_in_usd', data=df)
plt.figure(figsize=(10,6))

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Salary w.r.t experience

# %%
sns.boxplot(x='experience_level', y='salary_in_usd', data=df)
plt.figure(figsize=(10,6))

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Employee residence with highest salaries

# %%
res = df.groupby('employee_residence').salary_in_usd.mean().sort_values(ascending=False)
res = res.head()
plt.figure(figsize=(10,5.5))
sns.barplot(x=res.index, y=res.values)
plt.title('highest salary by employee residence')
plt.ylabel('salary in USD')
plt.show()

# %% [markdown]
# ### Employee residence with lowest salaries

# %%
res1 = df.groupby('employee_residence').salary_in_usd.mean().sort_values(ascending=True)
res1 = res1.head()

plt.figure(figsize=(10,10))
sns.barplot(x=res1.index, y=res1.values)
plt.title('lowest salary by employee residence')
plt.ylabel('salary in USD')
plt.show()

# %% [markdown]
# ### Salary w.r.t company size

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x=df['company_size'], y=df['salary_in_usd'], data=df).set_title('Salary by company size')
# Out:
# Text(0.5, 1.0, 'Salary by company size')

# %% [markdown]
# ##### Larger organisations are paying higher salaries to their employees as compared to medium and smaller companies.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Salary diff. w.r.t Remote ratio

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x=df['remote_ratio'], y=df['salary_in_usd'], data=df).set_title('Salary by remote ratio')
# Out:
# Text(0.5, 1.0, 'Salary by remote ratio')

# %% [markdown]
# ##### It can be observed that a majority of employees are doing W.F.H yet they are earning higher than F.T or 50 remote ratio ones.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Relative distribution by mode of work

# %%
remo = df['remote_ratio'].value_counts()
remo.plot.pie(labels=['Full remote', 'Partial remote', 'No remote'], shadow=True, autopct='%1.1f%%')
plt.title('employees by remote ratio')
plt.show()

# %% [markdown]
# ### Relative distribution by company size

# %%
df['company_size'].value_counts().plot.pie(shadow=True, autopct='%1.1f%%')
plt.title('Employees by Company Size')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Number of employees by year of joining

# %%
sns.countplot(data=df, x='work_year')
plt.title('Number of Employees by Year of Joining')
plt.show()

# %% [markdown]
# ##### There has been a significant amount of hiring in 2021 as compared to 2020. That is because the Number of jobs in the data science field have been increasing rapidly.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Employement status among countries

# %%
df['company_location'].value_counts().reset_index().set_index('index')
# Out:
#        company_location
# index
# US                  108
# DE                   19
# IN                   17
# GB                   16
# FR                   11
# CA                   11
# ES                    7
# JP                    4
# AT                    3
# NL                    3
# PL                    3
# DK                    3
# TR                    3
# BR                    2
# GR                    2
# PK                    2
# LU                    2
# CN                    2
# NG                    2
# RU                    2
# PT                    2
# MX                    2
# UA                    1
# IL                    1
# HR                    1
# AS                    1
# VN                    1
# MD                    1
# IT                    1
# CH                    1
# AE                    1
# SI                    1
# BE                    1
# CL                    1
# IR                    1
# NZ                    1
# CO                    1
# ...

# %% [markdown]
# ### Top 5 countries with hightest employment in Data related roles

# %%
cl = df['company_location'].value_counts().head()

plt.figure(figsize=(6,6))
plt.bar(cl.index, cl.values)
plt.ylabel('Number of employees')
plt.xlabel('Company location')
plt.title('Top 5 countries with highest number of employees')
plt.show()

# %% [markdown]
# ### Most popular job titles

# %%
from wordcloud import WordCloud, STOPWORDS

fig = plt.gcf()
fig.set_size_inches(15,8)
wc = WordCloud(stopwords=STOPWORDS,
              background_color='white',
              contour_width=3,
              contour_color='red',
              width=1250,
              height=800,
              max_words=250,
              max_font_size=250,
              random_state=42
              )

wc.generate(' '.join(df['job_title']))
fig= plt.imshow(wc, interpolation= "bilinear")
fig= plt.axis('off')

# %%
df['matched_location'] = df.apply(lambda x: x['company_location'] if x['company_location'].lower() == x['employee_residence'].lower() else np.nan, axis=1)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Company location vs Employee residence

# %%
lis = [df['company_location'].str.fullmatch(df['employee_residence'].at[idx], case=True).at[idx]
      for idx,i in enumerate(df['company_location'])]

print(lis)
# Out:
# [True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, False, True, False, True, True, True, True, True, False, True, True, True, True, True, True, False, True, True, True, False, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, False, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, False, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, False, False, True, True, True, False, True, True, False, True, True, True, True, False, True, True, True, True
# ...

# %%
pd.Series(lis).value_counts()
# Out:
# True     209
# False     36
# dtype: int64

# %% [markdown]
# ##### While some who are doing W.F.H are working remotely from a different location.
# ##### Most employees are living the same country as their company's location country.

# %%
pd.Series(lis, index=df.index).map({True:"Same residence-company loc",
                    False:"Diff residence-company loc"}).value_counts().plot(kind='bar', rot=10,
                                                                            title='Number of employees living same or different country-company location',
                                                                            figsize=(10,7),
                                                                            xlabel='same/diff country company location',
                                                                            ylabel='Number of employees',
                                                                            fontsize=15,
                                                                            )
# Out:
# <AxesSubplot:title={'center':'Number of employees living same or different country-company location'}, xlabel='same/diff country company location', ylabel='Number of employees'>

# %% [markdown]
# ##### 209 out of 245 workers are found to reside in the same nation as their employer.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Average salary as per Job title

# %%
plt.figure(figsize=(14, 12))
sns.barplot(x='salary_in_usd', y='job_title', data=df, ci=None, estimator=np.mean)
plt.xlabel("Average Salary in USD", size=20)
plt.ylabel('Job Title', size=20)
plt.title("Average Salary in USD for every Job Title", size=25)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Modelling

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size', 'matched_location'],
#       dtype='object')

# %%
X
# Out:
#      experience_level  company_location  job_title
# 0                   0                10         17
# 1                   3                39         20
# 2                   1                34         27
# 3                   1                34         26
# 4                   0                39         32
# ..                ...               ...        ...
# 240                 3                39         20
# 241                 2                39         39
# 242                 0                39         20
# 243                 0                39          7
# 244                 3                19         19
#
# [245 rows x 3 columns]

# %%
y =df[['salary_in_usd']]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
clf = DecisionTreeRegressor()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
le.fit(df['company_location'])
# Out:
# LabelEncoder()

# %%
le.transform(df['company_location'])
# Out:
# array([10, 39, 34, 34, 39, 39, 39, 13,  2,  5, 39, 38,  5, 39, 39, 39, 39,
#        39, 39, 28, 39, 19, 39,  5, 12, 32, 32, 39, 14, 39, 13, 39, 28, 39,
#        39, 10, 39, 39, 39, 39, 13, 39, 39, 12, 39, 10, 33, 11, 14, 14, 10,
#        19, 39, 39,  5, 14, 39, 14, 39, 39, 10, 39, 39, 39, 14, 35, 19, 39,
#        39, 39, 39, 39, 39, 39, 19, 33, 39, 13, 19, 27, 39, 14, 37, 13, 14,
#        39,  5, 39, 39,  5, 19, 29,  0,  5, 22, 39, 39, 39, 14, 39, 39, 39,
#        10, 39, 39, 29,  8, 39, 39, 37, 12, 39, 39, 13, 10, 10, 39, 39, 10,
#        37, 39, 39, 39, 10, 19, 19, 10, 39, 10, 19,  5, 17, 39, 10, 39, 19,
#        23, 39,  5, 39, 39,  9, 30, 13, 19, 12, 14, 20, 13, 39, 39, 10, 19,
#        39, 39,  7, 27, 39,  2, 39, 12, 39, 39,  5, 14, 19, 14, 32, 31, 22,
#        14,  3, 19, 39, 11, 10,  8, 19, 15, 39, 14, 13, 36, 39, 39, 39, 39,
#        11, 39, 39, 15, 39,  4, 39,  6, 13, 39, 10, 10, 21, 39, 39, 39,  5,
# ...

# %%
col_list = [ 'experience_level', 'company_location', 'job_title']

# %%
for i in col_list:
    df[i] = le.fit_transform(df[i])

# %%
X = df[[ 'experience_level', 'company_location', 'job_title']]

# %%
y =df[['salary_in_usd']]

# %%
X
# Out:
#      experience_level  company_location  job_title
# 0                   0                10         17
# 1                   3                39         20
# 2                   1                34         27
# 3                   1                34         26
# 4                   0                39         32
# ..                ...               ...        ...
# 240                 3                39         20
# 241                 2                39         39
# 242                 0                39         20
# 243                 0                39          7
# 244                 3                19         19
#
# [245 rows x 3 columns]

# %%
y
# Out:
#      salary_in_usd
# 0            64369
# 1            68428
# 2            85000
# 3           230000
# 4           125000
# ..             ...
# 240         412000
# 241         151000
# 242         105000
# 243         100000
# 244          94917
#
# [245 rows x 1 columns]

# %%
reg = DecisionTreeRegressor()

# %%
reg = reg.fit(X, y)

# %%
reg
# Out:
# DecisionTreeRegressor()

# %%
from sklearn import tree
tree.plot_tree(reg)
# Out:
# [Text(0.5899300441826215, 0.9705882352941176, 'X[1] <= 38.5\nsquared_error = 7024410637.261\nsamples = 245\nvalue = 99868.012'),
#  Text(0.3896354933726068, 0.9117647058823529, 'X[0] <= 2.5\nsquared_error = 2197236982.822\nsamples = 136\nvalue = 64685.713'),
#  Text(0.22956553755522827, 0.8529411764705882, 'X[1] <= 18.5\nsquared_error = 1547328940.395\nsamples = 98\nvalue = 53125.949'),
#  Text(0.1325478645066274, 0.7941176470588235, 'X[2] <= 36.5\nsquared_error = 1113563396.783\nsamples = 56\nvalue = 64189.696'),
#  Text(0.08836524300441827, 0.7352941176470589, 'X[0] <= 0.5\nsquared_error = 878271173.98\nsamples = 51\nvalue = 60833.686'),
#  Text(0.041237113402061855, 0.6764705882352942, 'X[1] <= 9.5\nsquared_error = 555347818.886\nsamples = 17\nvalue = 45999.765'),
#  Text(0.017673048600883652, 0.6176470588235294, 'X[2] <= 19.0\nsquared_error = 46357232.889\nsamples = 3\nvalue = 15281.333'),
# ...

# %%
plt.figure(figsize=(30,30))  # set plot size (denoted in inches)
tree.plot_tree(reg, fontsize=12)
plt.show()
